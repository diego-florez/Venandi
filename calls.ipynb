# %%
import requests

# %% [markdown]
# ### API Connect

# %%
url = "http://localhost:3500/"
requests.get(url).json()
# Out:
# {'hola cabron': 'que te follen'}

# %% [markdown]
# ### Get Users from Github

# %%
url = f"http://localhost:3500/user/madrid/jupyter/architect/get"

data = requests.get(url).text
print(data)
# Out:
# {
#   "0": {
#     "1. Name": "Antonio Leiva",
#     "2. Company": "Freelance Kotlin trainer",
#     "3. Location": "Madrid (Spain)",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 49,
#     "7. Number of Followers": 4730,
#     "8. Account Created at": "2012-08-19T10:55:29Z",
#     "9. Account Updated at": "2020-05-19T09:36:27Z"
#   },
#   "1": {
#     "1. Name": "Pedro Vicente G\u00f3mez S\u00e1nchez",
#     "2. Company": "Karumi",
#     "3. Location": "Madrid",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 63,
#     "7. Number of Followers": 3329,
#     "8. Account Created at": "2013-04-01T21:44:58Z",
#     "9. Account Updated at": "2020-05-20T12:52:01Z"
#   },
#   "2": {
#     "1. Name": "Manuel Peinado Gallego",
#     "2. Company": "@plexinc ",
#     "3. Location": "Madrid, Spain",
#     "4. Email": "manuel.peinado@gmail.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 33,
#     "7. Number of Followers": 2900,
#     "8. Account Created at": "2012-11-01T16:15:08Z",
#     "9. Account Updated at": "2020-05-03T08:40:53Z"
#   },
#   "3": {
#     "1. Name": "Carlos Azaustre",
#     "2. Company": "@eventbrite",
#     "3. Location": "Madrid, Spain",
#     "4. Email": "cazaustre@gmail.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 162,
#     "7. Number of Followers": 2193,
#     "8. Account Created at": "2011-03-04T10:48:06Z",
#     "9. Account Updated at": "2020-05-14T16:10:07Z"
#   },
#   "4": {
#     "1. Name": "Vicent Mart\u00ed",
#     "2. Company": "GitHub",
#     "3. Location": "Madrid",
#     "4. Email": "vicent@github.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 95,
#     "7. Number of Followers": 1383,
#     "8. Account Created at": "2008-12-26T20:21:00Z",
#     "9. Account Updated at": "2020-05-20T10:23:13Z"
#   },
#   "5": {
#     "1. Name": "Juan Gonzalez-Gomez",
#     "2. Company": "URJC",
#     "3. Location": "Madrid (Spain)",
#     "4. Email": "juan@iearobotics.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 123,
#     "7. Number of Followers": 1081,
#     "8. Account Created at": "2011-12-26T10:55:43Z",
#     "9. Account Updated at": "2020-05-12T11:08:57Z"
#   },
#   "6": {
#     "1. Name": "Greg Hurrell",
#     "2. Company": "Liferay",
#     "3. Location": "Madrid, Spain",
#     "4. Email": "greg@hurrell.net",
#     "5. Hireable": null,
#     "6. Number of Repositories": 178,
#     "7. Number of Followers": 1034,
#     "8. Account Created at": "2008-04-13T13:40:03Z",
#     "9. Account Updated at": "2020-05-14T17:35:57Z"
#   },
#   "7": {
#     "1. Name": "Alvaro Mu\u00f1oz",
#     "2. Company": "GitHub",
#     "3. Location": "Madrid, Spain",
#     "4. Email": "alvaro@pwntester.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 90,
#     "7. Number of Followers": 876,
#     "8. Account Created at": "2009-09-11T09:46:53Z",
#     "9. Account Updated at": "2020-05-15T22:29:06Z"
#   },
#   "8": {
#     "1. Name": "Ulises Gasc\u00f3n",
#     "2. Company": "@OSWeekends & @guidesmiths",
#     "3. Location": "Madrid",
#     "4. Email": null,
#     "5. Hireable": true,
#     "6. Number of Repositories": 91,
#     "7. Number of Followers": 702,
#     "8. Account Created at": "2013-07-29T06:55:12Z",
#     "9. Account Updated at": "2020-05-19T05:53:37Z"
#   },
#   "9": {
#     "1. Name": "Enrique Garc\u00eda Cota",
#     "2. Company": "@Kong",
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": true,
#     "6. Number of Repositories": 130,
#     "7. Number of Followers": 691,
#     "8. Account Created at": "2009-03-13T14:41:41Z",
#     "9. Account Updated at": "2020-03-10T10:51:04Z"
#   },
#   "10": {
#     "1. Name": "Gema Parre\u00f1o ",
#     "2. Company": null,
#     "3. Location": "Madrid",
#     "4. Email": "gema.parreno.piqueras@gmail.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 62,
#     "7. Number of Followers": 627,
#     "8. Account Created at": "2016-11-27T09:35:09Z",
#     "9. Account Updated at": "2020-05-11T10:51:55Z"
#   },
#   "11": {
#     "1. Name": "Andrey Antukh",
#     "2. Company": "@kaleidos,@taigaio & @uxbox ",
#     "3. Location": "Figueres (Girona), Madrid, Sofia (Bulgaria)",
#     "4. Email": "niwi@niwi.nz",
#     "5. Hireable": true,
#     "6. Number of Repositories": 127,
#     "7. Number of Followers": 557,
#     "8. Account Created at": "2011-06-11T10:12:34Z",
#     "9. Account Updated at": "2020-05-07T05:52:53Z"
#   },
#   "12": {
#     "1. Name": "Alexandro Sanchez",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": "alexandro@phi.nz",
#     "5. Hireable": true,
#     "6. Number of Repositories": 41,
#     "7. Number of Followers": 548,
#     "8. Account Created at": "2013-08-25T16:41:12Z",
#     "9. Account Updated at": "2020-05-19T06:03:53Z"
#   },
#   "13": {
#     "1. Name": "Juanpe Catal\u00e1n",
#     "2. Company": null,
#     "3. Location": "Madrid",
#     "4. Email": null,
#     "5. Hireable": true,
#     "6. Number of Repositories": 44,
#     "7. Number of Followers": 475,
#     "8. Account Created at": "2012-02-05T00:17:49Z",
#     "9. Account Updated at": "2020-05-19T08:41:52Z"
#   },
#   "14": {
#     "1. Name": "Mario Vilas",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": "mvilas@gmail.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 30,
#     "7. Number of Followers": 471,
#     "8. Account Created at": "2010-03-22T14:15:20Z",
#     "9. Account Updated at": "2020-04-24T14:10:49Z"
#   },
#   "15": {
#     "1. Name": "Boni Garc\u00eda",
#     "2. Company": "Universidad Carlos III de Madrid",
#     "3. Location": "Madrid",
#     "4. Email": "boni.garcia@uc3m.es",
#     "5. Hireable": true,
#     "6. Number of Repositories": 32,
#     "7. Number of Followers": 417,
#     "8. Account Created at": "2013-09-08T18:59:27Z",
#     "9. Account Updated at": "2020-04-23T17:25:23Z"
#   },
#   "16": {
#     "1. Name": "Vadim Markovtsev",
#     "2. Company": "@athenianco",
#     "3. Location": "Madrid",
#     "4. Email": "gmarkhor@gmail.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 207,
#     "7. Number of Followers": 392,
#     "8. Account Created at": "2012-11-14T06:39:09Z",
#     "9. Account Updated at": "2020-05-18T14:33:13Z"
#   },
#   "17": {
#     "1. Name": "cr0hn",
#     "2. Company": null,
#     "3. Location": "Madrid",
#     "4. Email": "cr0hn@cr0hn.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 114,
#     "7. Number of Followers": 388,
#     "8. Account Created at": "2013-04-06T09:59:00Z",
#     "9. Account Updated at": "2020-05-06T09:31:50Z"
#   },
#   "18": {
#     "1. Name": "Cristina Fern\u00e1ndez Sanz",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 56,
#     "7. Number of Followers": 364,
#     "8. Account Created at": "2014-03-22T10:20:59Z",
#     "9. Account Updated at": "2020-04-07T08:02:18Z"
#   },
#   "19": {
#     "1. Name": "Syk Houdeib",
#     "2. Company": "Lola Market",
#     "3. Location": "Madrid, Spain",
#     "4. Email": "syk.houdeib@gmail.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 54,
#     "7. Number of Followers": 357,
#     "8. Account Created at": "2017-06-05T11:15:45Z",
#     "9. Account Updated at": "2020-05-06T16:05:03Z"
#   },
#   "20": {
#     "1. Name": "Keyvan Akbary",
#     "2. Company": "@cabify",
#     "3. Location": "Madrid",
#     "4. Email": "me@keyvanakbary.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 39,
#     "7. Number of Followers": 349,
#     "8. Account Created at": "2011-04-08T09:19:00Z",
#     "9. Account Updated at": "2020-04-14T23:24:55Z"
#   },
#   "21": {
#     "1. Name": "Jes\u00fas Legan\u00e9s-Combarro",
#     "2. Company": "@botxo",
#     "3. Location": "Alcorc\u00f3n, Madrid, Spain",
#     "4. Email": "jesus.leganes.combarro@gmail.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 271,
#     "7. Number of Followers": 341,
#     "8. Account Created at": "2010-12-21T20:12:13Z",
#     "9. Account Updated at": "2020-05-20T06:32:05Z"
#   },
#   "22": {
#     "1. Name": "Iv\u00e1n L\u00f3pez",
#     "2. Company": "Object Computing, Inc. (OCI)",
#     "3. Location": "Madrid, Spain",
#     "4. Email": "lopez.ivan@gmail.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 124,
#     "7. Number of Followers": 319,
#     "8. Account Created at": "2011-01-12T10:09:56Z",
#     "9. Account Updated at": "2020-01-31T23:01:15Z"
#   },
#   "23": {
#     "1. Name": "David Rodr\u00edguez",
#     "2. Company": "@rubytogether, @tidelift",
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": true,
#     "6. Number of Repositories": 152,
#     "7. Number of Followers": 313,
#     "8. Account Created at": "2012-11-26T01:44:09Z",
#     "9. Account Updated at": "2020-05-19T17:46:09Z"
#   },
#   "24": {
#     "1. Name": "Yago",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": true,
#     "6. Number of Repositories": 39,
#     "7. Number of Followers": 309,
#     "8. Account Created at": "2013-07-13T11:52:50Z",
#     "9. Account Updated at": "2020-05-03T16:13:20Z"
#   },
#   "25": {
#     "1. Name": "Jorge del Casar",
#     "2. Company": "Sngular",
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 106,
#     "7. Number of Followers": 288,
#     "8. Account Created at": "2011-07-30T18:51:53Z",
#     "9. Account Updated at": "2020-05-18T14:04:13Z"
#   },
#   "26": {
#     "1. Name": "Miguel Molina",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 241,
#     "7. Number of Followers": 274,
#     "8. Account Created at": "2012-01-07T21:18:51Z",
#     "9. Account Updated at": "2020-04-30T07:17:02Z"
#   },
#   "27": {
#     "1. Name": "I\u00f1aki Baz Castillo",
#     "2. Company": null,
#     "3. Location": "Bilbao & Madrid",
#     "4. Email": "ibc@aliax.net",
#     "5. Hireable": true,
#     "6. Number of Repositories": 33,
#     "7. Number of Followers": 267,
#     "8. Account Created at": "2008-07-06T16:15:22Z",
#     "9. Account Updated at": "2020-05-20T18:33:04Z"
#   },
#   "28": {
#     "1. Name": "Jes\u00fas Arroyo Torrens",
#     "2. Company": "@CartoDB ",
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": true,
#     "6. Number of Repositories": 68,
#     "7. Number of Followers": 262,
#     "8. Account Created at": "2012-08-27T13:29:46Z",
#     "9. Account Updated at": "2020-05-05T17:13:38Z"
#   },
#   "29": {
#     "1. Name": "M\u00e1ximo Cuadros",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": "mcuadros@gmail.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 82,
#     "7. Number of Followers": 259,
#     "8. Account Created at": "2012-03-25T11:48:31Z",
#     "9. Account Updated at": "2020-05-20T17:16:03Z"
#   },
#   "30": {
#     "1. Name": "Adolfo Sanz De Diego",
#     "2. Company": null,
#     "3. Location": "Madrid",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 77,
#     "7. Number of Followers": 257,
#     "8. Account Created at": "2012-04-13T21:01:38Z",
#     "9. Account Updated at": "2020-04-28T21:30:41Z"
#   },
#   "31": {
#     "1. Name": "Miguel Araujo",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": "miguel.araujo.perez@gmail.com",
#     "5. Hireable": null,
#     "6. Number of Repositories": 71,
#     "7. Number of Followers": 255,
#     "8. Account Created at": "2010-04-26T00:34:07Z",
#     "9. Account Updated at": "2020-04-29T14:43:31Z"
#   }
# }

# %% [markdown]
# ### Predict User Seniority

# %%
url = f"http://localhost:3500/user/Clapiniella/predict"

data = requests.get(url).text
print(data)
# Out:
# middle
